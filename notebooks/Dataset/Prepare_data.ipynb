# %%
# ------------------------------------------define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.Tensorflow_helper import choose_gpu_by_id

# ------------------------------------------jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# ------------------------------------------ import helpers
# Notebook_imports should import glob, os, and many other standard libs
from src.utils.Notebook_imports import *
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/wft21_septum_landmark_detection

# %% [markdown]
# # Load CMR and mask file names

# %%
# get the 3D images and masks from the raw dir
input_path = '/mnt/ssd/data/WFT_MRT21/random_100_new'
export_path = '/mnt/ssd/data/WFT_MRT21/Export_random_100_new_' + str(datetime.datetime.now().strftime("%Y-%m-%d_%H_%M"))  #'/mnt/ssd/data/WFT_MRT21/patienten_21-30_export'  #add date
#AG: aktuell landen alle im selben Export-ordner, könnten wir abändern.


images = sorted(glob.glob(os.path.join(input_path, '**/**/*frame[0-9][0-9].nii.gz'))) #searches in all first level folders for any image / frame as nifti
masks = sorted(glob.glob(os.path.join(input_path, '**/**/*frame[0-9][0-9]_rvip.nrrd'))) #searches in all first level folders for any mask as nrrd
print('images: {}'.format(len(images)))
print('masks: {}'.format(len(masks)))
#print(images)
#print(masks)
# Out:
# images: 200
# masks: 200

# %%
from src.data.Dataset import ensure_dir, create_2d_slices_from_3d_volume_files

# %%
# Slice the images
ensure_dir(export_path)
[create_2d_slices_from_3d_volume_files(img_f=img,mask_f=msk, export_path=export_path) for img,msk in zip(images,masks)]


# from src.data.Dataset import create_2d_slices_from_3d_volume_files_new_naming
# ensure_dir(export_path)
# [create_2d_slices_from_3d_volume_files_new_naming(img_f=img,mask_f=msk, export_path=export_path) for img,msk in zip(images,masks)] # produces different names so multiple annotations of same patient are valid
# Out:
# [['01', [10, 256, 216]],
#  ['12', [10, 256, 216]],
#  ['01', [10, 256, 232]],
#  ['12', [10, 256, 232]],
#  ['01', [10, 256, 256]],
#  ['15', [10, 256, 256]],
#  ['01', [10, 256, 232]],
#  ['15', [10, 256, 232]],
#  ['01', [10, 216, 256]],
#  ['13', [10, 216, 256]],
#  ['01', [11, 256, 232]],
#  ['16', [11, 256, 232]],
#  ['01', [10, 224, 222]],
#  ['07', [10, 224, 222]],
#  ['01', [10, 256, 200]],
#  ['13', [10, 256, 200]],
#  ['01', [10, 256, 208]],
#  ['13', [10, 256, 208]],
#  ['01', [10, 256, 208]],
#  ['13', [10, 256, 208]],
#  ['01', [9, 256, 216]],
#  ['08', [9, 256, 216]],
#  ['01', [10, 256, 184]],
#  ['13', [10, 256, 184]],
#  ['01', [10, 256, 216]],
#  ['14', [10, 256, 216]],
#  ['01', [10, 216, 256]],
#  ['13', [10, 216, 256]],
#  ['01', [9, 216, 256]],
#  ['10', [9, 216, 256]],
#  ['01', [10, 256, 192]],
#  ['12', [10, 256, 192]],
#  ['01', [9, 256, 216]],
#  ['09', [9, 256, 216]],
#  ['01', [8, 256, 216]],
#  ['10', [8, 256, 216]],
#  ['01', [11, 256, 216]],
#  ['11', [11, 256, 216]],
#  ['01', [8, 256, 208]],
#  ['11', [8, 256, 208]],
#  ['01', [10, 256, 216]],
#  ['10', [10, 256, 216]],
#  ['01', [10, 256, 240]],
#  ['12', [10, 256, 240]],
#  ['01', [10, 256, 216]],
#  ['14', [10, 256, 216]],
#  ['01', [10, 256, 224]],
#  ['16', [10, 256, 224]],
#  ['01', [13, 256, 208]],
#  ['11', [13, 256, 208]],
#  ['01', [8, 256, 216]],
#  ['12', [8, 256, 216]],
#  ['01', [7, 256, 216]],
#  ['12', [7, 256, 216]],
#  ['01', [8, 384, 276]],
#  ['11', [8, 384, 276]],
#  ['01', [9, 256, 208]],
#  ['10', [9, 256, 208]],
#  ['01', [10, 256, 208]],
#  ['13', [10, 256, 208]],
#  ['01', [6, 224, 154]],
#  ['11', [6, 224, 154]],
#  ['01', [9, 256, 232]],
#  ['16', [9, 256, 232]],
#  ['01', [12, 224, 174]],
#  ['07', [12, 224, 174]],
#  ['01', [9, 216, 256]],
#  ['11', [9, 216, 256]],
#  ['01', [8, 256, 208]],
#  ['13', [8, 256, 208]],
#  ['01', [9, 216, 256]],
#  ['10', [9, 216, 256]],
#  ['01', [9, 208, 256]],
#  ['09', [9, 208, 256]],
#  ['01', [8, 256, 208]],
#  ['08', [8, 256, 208]],
#  ['01', [7, 216, 256]],
#  ['11', [7, 216, 256]],
#  ['01', [10, 256, 248]],
#  ['12', [10, 256, 248]],
#  ['01', [17, 224, 154]],
#  ['07', [17, 224, 154]],
#  ['01', [16, 154, 224]],
#  ['07', [16, 154, 224]],
#  ['01', [6, 256, 208]],
#  ['08', [6, 256, 208]],
#  ['01', [12, 256, 208]],
#  ['10', [12, 256, 208]],
#  ['01', [15, 288, 184]],
#  ['09', [15, 288, 184]],
#  ['01', [7, 256, 192]],
#  ['08', [7, 256, 192]],
#  ['01', [8, 184, 256]],
#  ['10', [8, 184, 256]],
#  ['01', [16, 154, 224]],
#  ['12', [16, 154, 224]],
#  ['01', [6, 288, 264]],
#  ['10', [6, 288, 264]],
#  ['04', [7, 224, 154]],
#  ['11', [7, 224, 154]],
#  ['01', [10, 256, 224]],
#  ['11', [10, 256, 224]],
#  ['01', [8, 256, 216]],
#  ['09', [8, 256, 216]],
#  ['01', [7, 256, 216]],
#  ['12', [7, 256, 216]],
#  ['01', [8, 256, 216]],
#  ['12', [8, 256, 216]],
#  ['01', [9, 216, 256]],
#  ['10', [9, 216, 256]],
#  ['01', [9, 256, 216]],
#  ['12', [9, 256, 216]],
#  ['01', [8, 512, 428]],
#  ['09', [8, 512, 428]],
#  ['01', [9, 256, 216]],
#  ['14', [9, 256, 216]],
#  ['01', [9, 216, 256]],
#  ['09', [9, 216, 256]],
#  ['01', [9, 256, 216]],
#  ['14', [9, 256, 216]],
#  ['01', [9, 256, 216]],
#  ['10', [9, 256, 216]],
#  ['01', [10, 216, 256]],
#  ['09', [10, 216, 256]],
#  ['01', [8, 176, 256]],
#  ['16', [8, 176, 256]],
#  ['01', [10, 256, 216]],
#  ['12', [10, 256, 216]],
#  ['01', [8, 224, 210]],
#  ['14', [8, 224, 210]],
#  ['01', [9, 256, 240]],
#  ['11', [9, 256, 240]],
#  ['01', [10, 216, 256]],
#  ['10', [10, 216, 256]],
#  ['01', [7, 208, 256]],
#  ['12', [7, 208, 256]],
#  ['01', [7, 256, 216]],
#  ['12', [7, 256, 216]],
#  ['01', [6, 256, 208]],
#  ['10', [6, 256, 208]],
#  ['01', [8, 224, 180]],
#  ['09', [8, 224, 180]],
#  ['01', [15, 208, 174]],
#  ['06', [15, 208, 174]],
#  ['01', [10, 224, 180]],
#  ['14', [10, 224, 180]],
#  ['01', [10, 174, 208]],
#  ['07', [10, 174, 208]],
#  ['01', [14, 224, 180]],
#  ['12', [14, 224, 180]],
#  ['01', [18, 208, 174]],
#  ['08', [18, 208, 174]],
#  ['01', [8, 256, 216]],
#  ['11', [8, 256, 216]],
#  ['01', [7, 256, 216]],
#  ['09', [7, 256, 216]],
#  ['01', [16, 224, 154]],
#  ['09', [16, 224, 154]],
#  ['01', [8, 304, 216]],
#  ['13', [8, 304, 216]],
#  ['01', [10, 256, 240]],
#  ['13', [10, 256, 240]],
#  ['01', [7, 256, 200]],
#  ['11', [7, 256, 200]],
#  ['01', [9, 256, 216]],
#  ['09', [9, 256, 216]],
#  ['01', [8, 256, 208]],
#  ['09', [8, 256, 208]],
#  ['01', [9, 256, 256]],
#  ['09', [9, 256, 256]],
#  ['01', [10, 256, 216]],
#  ['12', [10, 256, 216]],
#  ['01', [10, 256, 216]],
#  ['11', [10, 256, 216]],
#  ['01', [10, 256, 224]],
#  ['09', [10, 256, 224]],
#  ['01', [11, 256, 192]],
#  ['12', [11, 256, 192]],
#  ['01', [10, 256, 216]],
#  ['12', [10, 256, 216]],
#  ['01', [10, 256, 192]],
#  ['09', [10, 256, 192]],
#  ['01', [8, 256, 216]],
#  ['11', [8, 256, 216]],
#  ['01', [7, 256, 208]],
#  ['10', [7, 256, 208]],
#  ['01', [8, 256, 256]],
#  ['12', [8, 256, 256]],
#  ['01', [14, 224, 168]],
#  ['06', [14, 224, 168]],
#  ['01', [8, 256, 256]],
#  ['12', [8, 256, 256]],
#  ['01', [8, 256, 214]],
#  ['09', [8, 256, 214]],
#  ['01', [8, 256, 216]],
#  ['09', [8, 256, 216]],
#  ['01', [9, 256, 216]],
#  ['11', [9, 256, 216]],
#  ['01', [6, 256, 216]],
#  ['10', [6, 256, 216]]]
