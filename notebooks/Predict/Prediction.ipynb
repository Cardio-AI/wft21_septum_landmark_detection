# %% [markdown]
# # Use the model in a inference behaviour

# %% [markdown]
# 1. Load a cv config with all experiment parameters
# 2. Load the corresponding data,
# 3. create a train and validation generator with the given parameters, exclusive the augmentation parameters
# 4. reconstruct the model with the given parameters, (we have custom loss functions, simple model.load() will not work)
# 5. load and apply the corresponding weights (with respect to the distributed training strategy)
# 6. predict the target vectors with the train and val generators (make sure that we change the batchsize to 1, and avoid shuffle so that we get all files)
# 7. write the gt and predictions as numpy into the corresponding experiment folder

# %%
# ------------------------------------------define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.Tensorflow_helper import choose_gpu_by_id
# ------------------------------------------define GPU id/s to use
GPU_IDS = '0,1'
GPUS = choose_gpu_by_id(GPU_IDS)
print(GPUS)
# ------------------------------------------jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# ------------------------------------------ import helpers
# this should import glob, os, and some other standard libs to keep this cell clean
# local imports
from src.utils.Notebook_imports import *
from src.utils.Utils_io import Console_and_file_logger, init_config

# import external libs
from tensorflow.python.client import device_lib
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
import cv2
import pandas as pd
import numpy as np
import SimpleITK as sitk
from ipyfilechooser import FileChooser
from src.data.Generators import DataGenerator
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/wft21_septum_landmark_detection
# ['/gpu:0', '/gpu:1']

# %% [markdown]
# # Load a config into the global namespace

# %%
# Select config of training that you trained on. If Experiment Root was changed change the input-string of the FileChooser aswell.
exp_config_chooser = FileChooser(os.path.join(os.getcwd(),'exp/'), '')
display(exp_config_chooser)
@interact_manual
def load_config():

    global exp_config_chooser, config
    """
    load an experiment config
    """
    if 'exp_config_chooser' in globals():
        config_file  = exp_config_chooser.selected
    else:
        print('no config chooser found')

    # load the experiment config
    with open(config_file, encoding='utf-8') as data_file:
        config = json.loads(data_file.read())
    globals().update(config)
    Console_and_file_logger(EXPERIMENT, logging.INFO)
    logging.info('Loaded config for experiment: {}'.format(config['EXPERIMENT']))
# Out:
# FileChooser(path='/mnt/ssd/git/wft21_septum_landmark_detection/exp', filename='', title='HTML(value='', layout…
# interactive(children=(Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widge…

# %% [markdown]
# # Load Dataframe based on .csv with fold information.
# ## Manually input desired fold!

# %%
df = pd.read_csv(DF_FOLDS)
# df.head() # shows dataframe with all files and all folds


# Input fold on which you are working. Only the validation data of each fold will be predicted. 
# Load dataframe with all patients of the corresponding fold
df = df[df['fold']==0] 
df.head() 


# useful for troubleshooting , showcases entire dataframe:
# pd.set_option("display.max_rows", None, "display.max_columns", None) 
# print(df)
# Out:
#       fold modality pathology     patient  \
# 1344     0    train        RV  patient083
# 1345     0    train        RV  patient083
# 1346     0    train        RV  patient083
# 1347     0    train        RV  patient083
# 1348     0    train        RV  patient083
#
#                                                  x_path  \
# 1344  data/raw/ACDC/2D/train/patient083__t01_z0_img....
# 1345  data/raw/ACDC/2D/train/patient083__t01_z1_img....
# 1346  data/raw/ACDC/2D/train/patient083__t01_z2_img....
# 1347  data/raw/ACDC/2D/train/patient083__t01_z3_img....
# 1348  data/raw/ACDC/2D/train/patient083__t01_z4_img....
#
#                                                  y_path
# 1344  data/raw/ACDC/2D/train/patient083__t01_z0_msk....
# 1345  data/raw/ACDC/2D/train/patient083__t01_z1_msk....
# 1346  data/raw/ACDC/2D/train/patient083__t01_z2_msk....
# 1347  data/raw/ACDC/2D/train/patient083__t01_z3_msk....
# 1348  data/raw/ACDC/2D/train/patient083__t01_z4_msk....

# %% [markdown]
# # Pandas Dataframe

# %% [markdown]
# # Load the corresponding file names for this fold

# %%
# Load SAX volumes
from src.data.Dataset import get_trainings_files
x_train_sax, y_train_sax, x_val_sax, y_val_sax = get_trainings_files(data_path=DATA_PATH_SAX,
                                                                     path_to_folds_df=DF_FOLDS,
                                                                     fold=FOLD)
logging.info('SAX train CMR: {}, SAX train masks: {}'.format(len(x_train_sax), len(y_train_sax)))
logging.info('SAX val CMR: {}, SAX val masks: {}'.format(len(x_val_sax), len(y_val_sax)))
# Out:
# 2021-07-11 14:34:58,604 INFO Found 1902 images/masks in /mnt/ssd/data/WFT_MRT21/Export_2021-05-26_16_03
# 2021-07-11 14:34:58,604 INFO Patients train: 75
# 2021-07-11 14:34:58,664 INFO Selected 1406 of 1902 files with 75 of 100 patients for training fold 3
# 2021-07-11 14:34:58,665 INFO SAX train CMR: 1406, SAX train masks: 1406
# 2021-07-11 14:34:58,665 INFO SAX val CMR: 496, SAX val masks: 496

# %% [markdown]
# # Load the model, load and set the corresponding weights

# %%
# Load Neural Network based on config.
import src.models.Unets as modelmanager
# create a model
logging.info('Create model')
model = modelmanager.create_unet(config)
model.load_weights(os.path.join(config['MODEL_PATH'],'model.h5'))
logging.info('loaded model weights as h5 file')
model.summary()
# Out:
# 2021-07-11 14:34:11,679 INFO Create model
# using tensorflow, need to monkey patch
# tf.python.backend.slice overwritten by monkey patch
# (None, 128, 128, 1)
# 2021-07-11 14:34:13,288 INFO loaded model weights as h5 file
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 128)  512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 512)    1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 512)    2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 512)    2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  1179904     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 512)  0           conv2d_10[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  590080      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 128)  295040      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 256)  0           conv2d_13[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 128)  147584      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 64)   73792       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 128)  0           conv2d_16[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 64)   36928       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 32) 18464       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 64) 0           conv2d_19[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 9248        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# unet (Conv2D)                   (None, 128, 128, 2)  66          batch_normalization_17[0][0]
# ==================================================================================================
# Total params: 8,641,730
# Trainable params: 8,635,842
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # Save gt and pred into experiment folder
# saves groundtruth based on np.stack with gts and predictions as one numpy stack under the pred_filename as a .npy file. The numpy stack is later used to create the images based on the arrays

# %% [markdown]
# # fast hack which aligns the patients

# %%
# get a list of patients for fast testing
patients = [p for p in sorted(df['patient'].unique())]
#patients

# %% [markdown]
# Workaround to align data from generators with dataframe based on .csv.
# The idea is to create one generator per patient.
#
# This means that the original CMR picture and ground-truth are written out in new dimensions aswell, so the predictions can be compared and evaluated using our evaluation script and MITK. This shortcut enables us to skip undoing the generator steps.
#
# Each patient has two 3D-Volumes, corresponding to the end diastolic (ed) and end systolic (es) phase of the cardiac cycle.
# The amount of slices remain the same across volumes of the same patient, allowing us to sort the files and half them to reconstruct the corresponding two 3d-volumes.

# %%
# in short: create one generator per patient
# read config and initialize DataGenerator with given parameters, reading from config. Shuffle and Augmentation have to be off, Batchsize of 1 is required
# logging.getLogger().setLevel(logging.INFO)
from src.data.Generators import DataGenerator
from logging import info
config['SHUFFLE'] = False
config['AUGMENT'] = False
config['AUGMENT_GRID'] = False# make sure no augmentation will be applied to the validation data
config['HIST_MATCHING'] = False
config['BATCHSIZE'] = 1
# by this we can have a different set of parameters for both generators
val_config = config.copy()

# change export_root if needed
export_root = '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp_predictions/k-fold_fold3'
ensure_dir(export_root)

# only chose data from the test split of each cross-validation-fold
df_fold = df[df['modality']=='test']
#print(df_fold)

# filter a list of filenames by a patient id, this is necessary as the filepath in our df differs from the real filenames
def filter_by_patient_id(p_id, f_names):
    return [elem for elem in f_names if p_id in elem]


# show only data on 'unique' patients to sum up folds and slices
for p in sorted(df_fold['patient'].unique()): # for each patient
    info(p) # shows which patient we are at
    # load files and masks for given patient
    files_ = filter_by_patient_id(p, x_val_sax)
    masks_ = filter_by_patient_id(p, y_val_sax)
    info(len(files_)) # shows amount of slices for each patient
    # collect all files for this patient
    # split in ED and ES, using the fact that both have the same amount of slices and the data is sorted.
    ed_f = files_[:len(files_)//2]
    es_f = files_[len(files_)//2:]
    ed_m = masks_[:len(masks_)//2]
    es_m = masks_[len(masks_)//2:]
    f_ = [ed_f, es_f]
    m_ = [ed_m, es_m]
    phases = ['ED', 'ES']
    assert(len(ed_m)==len(ed_f)), 'number of images and masks should be the same, something went wrong'
    info('length of ed_f ' + str(len(ed_f)))
    info('length of es_f ' + str(len(es_f)))
    #print('this is ed_f ' + ed_f)
    #print('this is es_f ' + es_f)
    
    # the following is looped twice so both phases, ED and ES are processed.
    for p_ in range(2):
        phase_cmr_files = f_[p_] 
        phase_mask_files = m_[p_]
        current_phase = phases[p_]
        info('patient: {}, phase: {}, files: {}'.format(p, current_phase, len(phase_cmr_files)))
        
        # create validation generator just for the given patient and fold. This means that each patient requires two generators. The work around allows us to align the info from the .csv with the data from the generators. 
        validation_generator = DataGenerator(phase_cmr_files, phase_mask_files, config=val_config)

        # get cmr mask and save in a numpy.stack
        gts = np.stack([np.squeeze(y) for x, y in validation_generator])
        logging.info('groundtruth shape' + str(gts.shape))
        #get cmr image and save in a numpy stack
        gts_cmr = np.stack([np.squeeze(x) for x, y in validation_generator])
        logging.info('original cmr shape' + str(gts_cmr.shape))

        # predict on the validation generator
        preds = model.predict(validation_generator)
        logging.info(preds.shape)

        # upper_RVIP = 1, lower_RVIP == 2. Corresponds to annotation guide. 
        # transform to int representation (one-hot-encoded)
        # create data based on ground-truth
        gts_flat = np.zeros((gts.shape[:-1]))
        gts_flat[gts[...,0]>0.5] = 1
        gts_flat[gts[...,1]>0.5] = 2
        
        # create data based on predictions
        preds_flat = np.zeros((gts.shape[:-1]))
        preds_flat[preds[...,0]>0.5] = 1
        preds_flat[preds[...,1]>0.5] = 2
        
        info(gts_flat.shape)
        info(preds_flat.shape)
        info(gts_cmr.shape)
        
        # Read image data from Array using sitk library
        gt_sitks = sitk.GetImageFromArray(gts_flat.astype(np.uint8))
        pred_sitks = sitk.GetImageFromArray(preds_flat.astype(np.uint8))
        gt_cmr_sitks = sitk.GetImageFromArray(np.stack(gts_cmr, axis = 0))
        
     
        # Writing images to storage from previously loaded images. 
        sitk.WriteImage(gt_sitks, os.path.join(export_root, '{}_{}_gt.nrrd'.format(p, current_phase)))
        sitk.WriteImage(pred_sitks, os.path.join(export_root, '{}_{}_pred.nrrd'.format(p, current_phase)))
        sitk.WriteImage(gt_cmr_sitks, os.path.join(export_root, '{}_{}_cmr.nrrd'.format(p, current_phase)))
        #sitk.WriteImage(sitk.GetImageFromArray(np.stack(gts_cmr[:10], axis=0)), '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/3d_new_temp_cmr.nrrd')

logging.info('done! Check the ' + export_root + 'folder for files')
# Out:
# 2021-07-11 14:35:08,166 INFO patient007
# 2021-07-11 14:35:08,166 INFO 20
# 2021-07-11 14:35:08,167 INFO length of ed_f 10
# 2021-07-11 14:35:08,167 INFO length of es_f 10
# 2021-07-11 14:35:08,167 INFO patient: patient007, phase: ED, files: 10
# 2021-07-11 14:35:08,168 INFO Create DataGenerator
# 2021-07-11 14:35:08,168 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:08,169 INFO No augmentation
# 2021-07-11 14:35:08,236 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:08,270 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:09,926 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:09,928 INFO (10, 128, 128)
# 2021-07-11 14:35:09,929 INFO (10, 128, 128)
# 2021-07-11 14:35:09,929 INFO (10, 128, 128)
# 2021-07-11 14:35:09,932 INFO patient: patient007, phase: ES, files: 10
# 2021-07-11 14:35:09,933 INFO Create DataGenerator
# 2021-07-11 14:35:09,933 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:09,934 INFO No augmentation
# 2021-07-11 14:35:09,968 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:10,002 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:10,153 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:10,155 INFO (10, 128, 128)
# 2021-07-11 14:35:10,155 INFO (10, 128, 128)
# 2021-07-11 14:35:10,155 INFO (10, 128, 128)
# 2021-07-11 14:35:10,158 INFO patient008
# 2021-07-11 14:35:10,159 INFO 20
# 2021-07-11 14:35:10,159 INFO length of ed_f 10
# 2021-07-11 14:35:10,160 INFO length of es_f 10
# 2021-07-11 14:35:10,160 INFO patient: patient008, phase: ED, files: 10
# 2021-07-11 14:35:10,160 INFO Create DataGenerator
# 2021-07-11 14:35:10,161 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:10,161 INFO No augmentation
# 2021-07-11 14:35:10,197 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:10,231 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:10,378 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:10,380 INFO (10, 128, 128)
# 2021-07-11 14:35:10,380 INFO (10, 128, 128)
# 2021-07-11 14:35:10,380 INFO (10, 128, 128)
# 2021-07-11 14:35:10,383 INFO patient: patient008, phase: ES, files: 10
# 2021-07-11 14:35:10,383 INFO Create DataGenerator
# 2021-07-11 14:35:10,384 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:10,384 INFO No augmentation
# 2021-07-11 14:35:10,416 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:10,450 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:10,593 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:10,595 INFO (10, 128, 128)
# 2021-07-11 14:35:10,595 INFO (10, 128, 128)
# 2021-07-11 14:35:10,595 INFO (10, 128, 128)
# 2021-07-11 14:35:10,597 INFO patient011
# 2021-07-11 14:35:10,598 INFO 18
# 2021-07-11 14:35:10,598 INFO length of ed_f 9
# 2021-07-11 14:35:10,598 INFO length of es_f 9
# 2021-07-11 14:35:10,599 INFO patient: patient011, phase: ED, files: 9
# 2021-07-11 14:35:10,599 INFO Create DataGenerator
# 2021-07-11 14:35:10,599 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:10,600 INFO No augmentation
# 2021-07-11 14:35:10,629 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:10,660 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:10,810 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:10,811 INFO (9, 128, 128)
# 2021-07-11 14:35:10,811 INFO (9, 128, 128)
# 2021-07-11 14:35:10,812 INFO (9, 128, 128)
# 2021-07-11 14:35:10,814 INFO patient: patient011, phase: ES, files: 9
# 2021-07-11 14:35:10,815 INFO Create DataGenerator
# 2021-07-11 14:35:10,815 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:10,816 INFO No augmentation
# 2021-07-11 14:35:10,846 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:10,876 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:11,021 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:11,022 INFO (9, 128, 128)
# 2021-07-11 14:35:11,023 INFO (9, 128, 128)
# 2021-07-11 14:35:11,023 INFO (9, 128, 128)
# 2021-07-11 14:35:11,025 INFO patient013
# 2021-07-11 14:35:11,026 INFO 20
# 2021-07-11 14:35:11,026 INFO length of ed_f 10
# 2021-07-11 14:35:11,026 INFO length of es_f 10
# 2021-07-11 14:35:11,027 INFO patient: patient013, phase: ED, files: 10
# 2021-07-11 14:35:11,027 INFO Create DataGenerator
# 2021-07-11 14:35:11,027 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:11,028 INFO No augmentation
# 2021-07-11 14:35:11,061 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:11,095 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:11,247 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:11,249 INFO (10, 128, 128)
# 2021-07-11 14:35:11,249 INFO (10, 128, 128)
# 2021-07-11 14:35:11,250 INFO (10, 128, 128)
# 2021-07-11 14:35:11,252 INFO patient: patient013, phase: ES, files: 10
# 2021-07-11 14:35:11,252 INFO Create DataGenerator
# 2021-07-11 14:35:11,253 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:11,253 INFO No augmentation
# 2021-07-11 14:35:11,287 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:11,321 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:11,471 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:11,473 INFO (10, 128, 128)
# 2021-07-11 14:35:11,473 INFO (10, 128, 128)
# 2021-07-11 14:35:11,474 INFO (10, 128, 128)
# 2021-07-11 14:35:11,476 INFO patient015
# 2021-07-11 14:35:11,476 INFO 18
# 2021-07-11 14:35:11,477 INFO length of ed_f 9
# 2021-07-11 14:35:11,477 INFO length of es_f 9
# 2021-07-11 14:35:11,477 INFO patient: patient015, phase: ED, files: 9
# 2021-07-11 14:35:11,478 INFO Create DataGenerator
# 2021-07-11 14:35:11,478 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:11,479 INFO No augmentation
# 2021-07-11 14:35:11,510 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:11,541 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:11,685 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:11,687 INFO (9, 128, 128)
# 2021-07-11 14:35:11,687 INFO (9, 128, 128)
# 2021-07-11 14:35:11,688 INFO (9, 128, 128)
# 2021-07-11 14:35:11,690 INFO patient: patient015, phase: ES, files: 9
# 2021-07-11 14:35:11,690 INFO Create DataGenerator
# 2021-07-11 14:35:11,690 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:11,690 INFO No augmentation
# 2021-07-11 14:35:11,721 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:11,752 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:11,904 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:11,906 INFO (9, 128, 128)
# 2021-07-11 14:35:11,906 INFO (9, 128, 128)
# 2021-07-11 14:35:11,906 INFO (9, 128, 128)
# 2021-07-11 14:35:11,908 INFO patient027
# 2021-07-11 14:35:11,909 INFO 20
# 2021-07-11 14:35:11,909 INFO length of ed_f 10
# 2021-07-11 14:35:11,909 INFO length of es_f 10
# 2021-07-11 14:35:11,910 INFO patient: patient027, phase: ED, files: 10
# 2021-07-11 14:35:11,910 INFO Create DataGenerator
# 2021-07-11 14:35:11,910 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:11,911 INFO No augmentation
# 2021-07-11 14:35:11,945 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:11,981 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:12,125 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:12,127 INFO (10, 128, 128)
# 2021-07-11 14:35:12,127 INFO (10, 128, 128)
# 2021-07-11 14:35:12,128 INFO (10, 128, 128)
# 2021-07-11 14:35:12,130 INFO patient: patient027, phase: ES, files: 10
# 2021-07-11 14:35:12,130 INFO Create DataGenerator
# 2021-07-11 14:35:12,131 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:12,131 INFO No augmentation
# 2021-07-11 14:35:12,166 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:12,202 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:12,351 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:12,353 INFO (10, 128, 128)
# 2021-07-11 14:35:12,353 INFO (10, 128, 128)
# 2021-07-11 14:35:12,354 INFO (10, 128, 128)
# 2021-07-11 14:35:12,356 INFO patient028
# 2021-07-11 14:35:12,357 INFO 20
# 2021-07-11 14:35:12,357 INFO length of ed_f 10
# 2021-07-11 14:35:12,358 INFO length of es_f 10
# 2021-07-11 14:35:12,358 INFO patient: patient028, phase: ED, files: 10
# 2021-07-11 14:35:12,359 INFO Create DataGenerator
# 2021-07-11 14:35:12,359 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:12,360 INFO No augmentation
# 2021-07-11 14:35:12,393 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:12,426 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:12,578 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:12,580 INFO (10, 128, 128)
# 2021-07-11 14:35:12,580 INFO (10, 128, 128)
# 2021-07-11 14:35:12,580 INFO (10, 128, 128)
# 2021-07-11 14:35:12,583 INFO patient: patient028, phase: ES, files: 10
# 2021-07-11 14:35:12,583 INFO Create DataGenerator
# 2021-07-11 14:35:12,583 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:12,584 INFO No augmentation
# 2021-07-11 14:35:12,617 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:12,651 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:12,808 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:12,810 INFO (10, 128, 128)
# 2021-07-11 14:35:12,810 INFO (10, 128, 128)
# 2021-07-11 14:35:12,811 INFO (10, 128, 128)
# 2021-07-11 14:35:12,813 INFO patient031
# 2021-07-11 14:35:12,813 INFO 20
# 2021-07-11 14:35:12,814 INFO length of ed_f 10
# 2021-07-11 14:35:12,814 INFO length of es_f 10
# 2021-07-11 14:35:12,814 INFO patient: patient031, phase: ED, files: 10
# 2021-07-11 14:35:12,815 INFO Create DataGenerator
# 2021-07-11 14:35:12,815 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:12,815 INFO No augmentation
# 2021-07-11 14:35:12,848 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:12,883 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:13,044 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:13,045 INFO (10, 128, 128)
# 2021-07-11 14:35:13,046 INFO (10, 128, 128)
# 2021-07-11 14:35:13,046 INFO (10, 128, 128)
# 2021-07-11 14:35:13,049 INFO patient: patient031, phase: ES, files: 10
# 2021-07-11 14:35:13,049 INFO Create DataGenerator
# 2021-07-11 14:35:13,050 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:13,050 INFO No augmentation
# 2021-07-11 14:35:13,084 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:13,115 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:13,290 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:13,292 INFO (10, 128, 128)
# 2021-07-11 14:35:13,292 INFO (10, 128, 128)
# 2021-07-11 14:35:13,293 INFO (10, 128, 128)
# 2021-07-11 14:35:13,296 INFO patient033
# 2021-07-11 14:35:13,296 INFO 20
# 2021-07-11 14:35:13,296 INFO length of ed_f 10
# 2021-07-11 14:35:13,297 INFO length of es_f 10
# 2021-07-11 14:35:13,297 INFO patient: patient033, phase: ED, files: 10
# 2021-07-11 14:35:13,297 INFO Create DataGenerator
# 2021-07-11 14:35:13,298 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:13,298 INFO No augmentation
# 2021-07-11 14:35:13,339 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:13,375 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:13,529 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:13,531 INFO (10, 128, 128)
# 2021-07-11 14:35:13,531 INFO (10, 128, 128)
# 2021-07-11 14:35:13,532 INFO (10, 128, 128)
# 2021-07-11 14:35:13,535 INFO patient: patient033, phase: ES, files: 10
# 2021-07-11 14:35:13,535 INFO Create DataGenerator
# 2021-07-11 14:35:13,535 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:13,536 INFO No augmentation
# 2021-07-11 14:35:13,570 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:13,604 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:13,750 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:13,751 INFO (10, 128, 128)
# 2021-07-11 14:35:13,751 INFO (10, 128, 128)
# 2021-07-11 14:35:13,752 INFO (10, 128, 128)
# 2021-07-11 14:35:13,754 INFO patient035
# 2021-07-11 14:35:13,755 INFO 26
# 2021-07-11 14:35:13,755 INFO length of ed_f 13
# 2021-07-11 14:35:13,756 INFO length of es_f 13
# 2021-07-11 14:35:13,756 INFO patient: patient035, phase: ED, files: 13
# 2021-07-11 14:35:13,757 INFO Create DataGenerator
# 2021-07-11 14:35:13,757 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 13
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:13,757 INFO No augmentation
# 2021-07-11 14:35:13,801 INFO groundtruth shape(13, 128, 128, 2)
# 2021-07-11 14:35:13,844 INFO original cmr shape(13, 128, 128)
# 2021-07-11 14:35:14,001 INFO (13, 128, 128, 2)
# 2021-07-11 14:35:14,003 INFO (13, 128, 128)
# 2021-07-11 14:35:14,003 INFO (13, 128, 128)
# 2021-07-11 14:35:14,004 INFO (13, 128, 128)
# 2021-07-11 14:35:14,006 INFO patient: patient035, phase: ES, files: 13
# 2021-07-11 14:35:14,007 INFO Create DataGenerator
# 2021-07-11 14:35:14,007 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 13
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:14,008 INFO No augmentation
# 2021-07-11 14:35:14,051 INFO groundtruth shape(13, 128, 128, 2)
# 2021-07-11 14:35:14,094 INFO original cmr shape(13, 128, 128)
# 2021-07-11 14:35:14,266 INFO (13, 128, 128, 2)
# 2021-07-11 14:35:14,268 INFO (13, 128, 128)
# 2021-07-11 14:35:14,268 INFO (13, 128, 128)
# 2021-07-11 14:35:14,268 INFO (13, 128, 128)
# 2021-07-11 14:35:14,271 INFO patient047
# 2021-07-11 14:35:14,271 INFO 18
# 2021-07-11 14:35:14,271 INFO length of ed_f 9
# 2021-07-11 14:35:14,272 INFO length of es_f 9
# 2021-07-11 14:35:14,272 INFO patient: patient047, phase: ED, files: 9
# 2021-07-11 14:35:14,272 INFO Create DataGenerator
# 2021-07-11 14:35:14,273 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:14,273 INFO No augmentation
# 2021-07-11 14:35:14,303 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:14,333 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:14,477 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:14,479 INFO (9, 128, 128)
# 2021-07-11 14:35:14,479 INFO (9, 128, 128)
# 2021-07-11 14:35:14,479 INFO (9, 128, 128)
# 2021-07-11 14:35:14,482 INFO patient: patient047, phase: ES, files: 9
# 2021-07-11 14:35:14,482 INFO Create DataGenerator
# 2021-07-11 14:35:14,482 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:14,483 INFO No augmentation
# 2021-07-11 14:35:14,513 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:14,544 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:14,689 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:14,691 INFO (9, 128, 128)
# 2021-07-11 14:35:14,691 INFO (9, 128, 128)
# 2021-07-11 14:35:14,692 INFO (9, 128, 128)
# 2021-07-11 14:35:14,694 INFO patient048
# 2021-07-11 14:35:14,694 INFO 16
# 2021-07-11 14:35:14,694 INFO length of ed_f 8
# 2021-07-11 14:35:14,695 INFO length of es_f 8
# 2021-07-11 14:35:14,695 INFO patient: patient048, phase: ED, files: 8
# 2021-07-11 14:35:14,695 INFO Create DataGenerator
# 2021-07-11 14:35:14,695 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:14,696 INFO No augmentation
# 2021-07-11 14:35:14,721 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 14:35:14,749 INFO original cmr shape(8, 128, 128)
# 2021-07-11 14:35:14,899 INFO (8, 128, 128, 2)
# 2021-07-11 14:35:14,900 INFO (8, 128, 128)
# 2021-07-11 14:35:14,900 INFO (8, 128, 128)
# 2021-07-11 14:35:14,900 INFO (8, 128, 128)
# 2021-07-11 14:35:14,902 INFO patient: patient048, phase: ES, files: 8
# 2021-07-11 14:35:14,903 INFO Create DataGenerator
# 2021-07-11 14:35:14,903 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:14,903 INFO No augmentation
# 2021-07-11 14:35:14,931 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 14:35:14,956 INFO original cmr shape(8, 128, 128)
# 2021-07-11 14:35:15,095 INFO (8, 128, 128, 2)
# 2021-07-11 14:35:15,096 INFO (8, 128, 128)
# 2021-07-11 14:35:15,097 INFO (8, 128, 128)
# 2021-07-11 14:35:15,097 INFO (8, 128, 128)
# 2021-07-11 14:35:15,099 INFO patient051
# 2021-07-11 14:35:15,099 INFO 20
# 2021-07-11 14:35:15,100 INFO length of ed_f 10
# 2021-07-11 14:35:15,100 INFO length of es_f 10
# 2021-07-11 14:35:15,101 INFO patient: patient051, phase: ED, files: 10
# 2021-07-11 14:35:15,101 INFO Create DataGenerator
# 2021-07-11 14:35:15,101 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:15,102 INFO No augmentation
# 2021-07-11 14:35:15,137 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:15,170 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:15,318 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:15,319 INFO (10, 128, 128)
# 2021-07-11 14:35:15,319 INFO (10, 128, 128)
# 2021-07-11 14:35:15,320 INFO (10, 128, 128)
# 2021-07-11 14:35:15,322 INFO patient: patient051, phase: ES, files: 10
# 2021-07-11 14:35:15,322 INFO Create DataGenerator
# 2021-07-11 14:35:15,323 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:15,323 INFO No augmentation
# 2021-07-11 14:35:15,356 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:15,389 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:15,534 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:15,536 INFO (10, 128, 128)
# 2021-07-11 14:35:15,536 INFO (10, 128, 128)
# 2021-07-11 14:35:15,537 INFO (10, 128, 128)
# 2021-07-11 14:35:15,539 INFO patient053
# 2021-07-11 14:35:15,539 INFO 14
# 2021-07-11 14:35:15,539 INFO length of ed_f 7
# 2021-07-11 14:35:15,540 INFO length of es_f 7
# 2021-07-11 14:35:15,540 INFO patient: patient053, phase: ED, files: 7
# 2021-07-11 14:35:15,540 INFO Create DataGenerator
# 2021-07-11 14:35:15,540 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:15,541 INFO No augmentation
# 2021-07-11 14:35:15,563 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 14:35:15,585 INFO original cmr shape(7, 128, 128)
# 2021-07-11 14:35:15,724 INFO (7, 128, 128, 2)
# 2021-07-11 14:35:15,726 INFO (7, 128, 128)
# 2021-07-11 14:35:15,726 INFO (7, 128, 128)
# 2021-07-11 14:35:15,726 INFO (7, 128, 128)
# 2021-07-11 14:35:15,728 INFO patient: patient053, phase: ES, files: 7
# 2021-07-11 14:35:15,729 INFO Create DataGenerator
# 2021-07-11 14:35:15,729 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:15,729 INFO No augmentation
# 2021-07-11 14:35:15,753 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 14:35:15,775 INFO original cmr shape(7, 128, 128)
# 2021-07-11 14:35:15,914 INFO (7, 128, 128, 2)
# 2021-07-11 14:35:15,915 INFO (7, 128, 128)
# 2021-07-11 14:35:15,915 INFO (7, 128, 128)
# 2021-07-11 14:35:15,915 INFO (7, 128, 128)
# 2021-07-11 14:35:15,918 INFO patient055
# 2021-07-11 14:35:15,919 INFO 18
# 2021-07-11 14:35:15,919 INFO length of ed_f 9
# 2021-07-11 14:35:15,919 INFO length of es_f 9
# 2021-07-11 14:35:15,920 INFO patient: patient055, phase: ED, files: 9
# 2021-07-11 14:35:15,920 INFO Create DataGenerator
# 2021-07-11 14:35:15,921 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:15,921 INFO No augmentation
# 2021-07-11 14:35:15,953 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:15,986 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:16,141 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:16,142 INFO (9, 128, 128)
# 2021-07-11 14:35:16,143 INFO (9, 128, 128)
# 2021-07-11 14:35:16,143 INFO (9, 128, 128)
# 2021-07-11 14:35:16,146 INFO patient: patient055, phase: ES, files: 9
# 2021-07-11 14:35:16,146 INFO Create DataGenerator
# 2021-07-11 14:35:16,147 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 9
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:16,147 INFO No augmentation
# 2021-07-11 14:35:16,177 INFO groundtruth shape(9, 128, 128, 2)
# 2021-07-11 14:35:16,208 INFO original cmr shape(9, 128, 128)
# 2021-07-11 14:35:16,363 INFO (9, 128, 128, 2)
# 2021-07-11 14:35:16,364 INFO (9, 128, 128)
# 2021-07-11 14:35:16,365 INFO (9, 128, 128)
# 2021-07-11 14:35:16,365 INFO (9, 128, 128)
# 2021-07-11 14:35:16,367 INFO patient067
# 2021-07-11 14:35:16,368 INFO 20
# 2021-07-11 14:35:16,368 INFO length of ed_f 10
# 2021-07-11 14:35:16,369 INFO length of es_f 10
# 2021-07-11 14:35:16,369 INFO patient: patient067, phase: ED, files: 10
# 2021-07-11 14:35:16,369 INFO Create DataGenerator
# 2021-07-11 14:35:16,371 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:16,371 INFO No augmentation
# 2021-07-11 14:35:16,403 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:16,434 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:16,579 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:16,581 INFO (10, 128, 128)
# 2021-07-11 14:35:16,581 INFO (10, 128, 128)
# 2021-07-11 14:35:16,581 INFO (10, 128, 128)
# 2021-07-11 14:35:16,584 INFO patient: patient067, phase: ES, files: 10
# 2021-07-11 14:35:16,585 INFO Create DataGenerator
# 2021-07-11 14:35:16,585 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:16,585 INFO No augmentation
# 2021-07-11 14:35:16,617 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:16,649 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:16,888 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:16,889 INFO (10, 128, 128)
# 2021-07-11 14:35:16,890 INFO (10, 128, 128)
# 2021-07-11 14:35:16,890 INFO (10, 128, 128)
# 2021-07-11 14:35:16,892 INFO patient068
# 2021-07-11 14:35:16,893 INFO 14
# 2021-07-11 14:35:16,893 INFO length of ed_f 7
# 2021-07-11 14:35:16,893 INFO length of es_f 7
# 2021-07-11 14:35:16,893 INFO patient: patient068, phase: ED, files: 7
# 2021-07-11 14:35:16,894 INFO Create DataGenerator
# 2021-07-11 14:35:16,894 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:16,895 INFO No augmentation
# 2021-07-11 14:35:16,920 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 14:35:16,944 INFO original cmr shape(7, 128, 128)
# 2021-07-11 14:35:17,082 INFO (7, 128, 128, 2)
# 2021-07-11 14:35:17,083 INFO (7, 128, 128)
# 2021-07-11 14:35:17,084 INFO (7, 128, 128)
# 2021-07-11 14:35:17,084 INFO (7, 128, 128)
# 2021-07-11 14:35:17,086 INFO patient: patient068, phase: ES, files: 7
# 2021-07-11 14:35:17,087 INFO Create DataGenerator
# 2021-07-11 14:35:17,087 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:17,088 INFO No augmentation
# 2021-07-11 14:35:17,112 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 14:35:17,135 INFO original cmr shape(7, 128, 128)
# 2021-07-11 14:35:17,283 INFO (7, 128, 128, 2)
# 2021-07-11 14:35:17,285 INFO (7, 128, 128)
# 2021-07-11 14:35:17,285 INFO (7, 128, 128)
# 2021-07-11 14:35:17,285 INFO (7, 128, 128)
# 2021-07-11 14:35:17,287 INFO patient071
# 2021-07-11 14:35:17,288 INFO 20
# 2021-07-11 14:35:17,288 INFO length of ed_f 10
# 2021-07-11 14:35:17,288 INFO length of es_f 10
# 2021-07-11 14:35:17,289 INFO patient: patient071, phase: ED, files: 10
# 2021-07-11 14:35:17,289 INFO Create DataGenerator
# 2021-07-11 14:35:17,289 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:17,290 INFO No augmentation
# 2021-07-11 14:35:17,323 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:17,356 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:17,502 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:17,503 INFO (10, 128, 128)
# 2021-07-11 14:35:17,503 INFO (10, 128, 128)
# 2021-07-11 14:35:17,504 INFO (10, 128, 128)
# 2021-07-11 14:35:17,506 INFO patient: patient071, phase: ES, files: 10
# 2021-07-11 14:35:17,506 INFO Create DataGenerator
# 2021-07-11 14:35:17,507 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:17,507 INFO No augmentation
# 2021-07-11 14:35:17,540 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:17,572 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:17,719 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:17,721 INFO (10, 128, 128)
# 2021-07-11 14:35:17,721 INFO (10, 128, 128)
# 2021-07-11 14:35:17,722 INFO (10, 128, 128)
# 2021-07-11 14:35:17,724 INFO patient073
# 2021-07-11 14:35:17,724 INFO 14
# 2021-07-11 14:35:17,724 INFO length of ed_f 7
# 2021-07-11 14:35:17,725 INFO length of es_f 7
# 2021-07-11 14:35:17,725 INFO patient: patient073, phase: ED, files: 7
# 2021-07-11 14:35:17,725 INFO Create DataGenerator
# 2021-07-11 14:35:17,725 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:17,726 INFO No augmentation
# 2021-07-11 14:35:17,750 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 14:35:17,774 INFO original cmr shape(7, 128, 128)
# 2021-07-11 14:35:17,914 INFO (7, 128, 128, 2)
# 2021-07-11 14:35:17,915 INFO (7, 128, 128)
# 2021-07-11 14:35:17,915 INFO (7, 128, 128)
# 2021-07-11 14:35:17,916 INFO (7, 128, 128)
# 2021-07-11 14:35:17,918 INFO patient: patient073, phase: ES, files: 7
# 2021-07-11 14:35:17,918 INFO Create DataGenerator
# 2021-07-11 14:35:17,918 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 7
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:17,918 INFO No augmentation
# 2021-07-11 14:35:17,943 INFO groundtruth shape(7, 128, 128, 2)
# 2021-07-11 14:35:17,966 INFO original cmr shape(7, 128, 128)
# 2021-07-11 14:35:18,100 INFO (7, 128, 128, 2)
# 2021-07-11 14:35:18,101 INFO (7, 128, 128)
# 2021-07-11 14:35:18,101 INFO (7, 128, 128)
# 2021-07-11 14:35:18,102 INFO (7, 128, 128)
# 2021-07-11 14:35:18,104 INFO patient075
# 2021-07-11 14:35:18,104 INFO 28
# 2021-07-11 14:35:18,105 INFO length of ed_f 14
# 2021-07-11 14:35:18,105 INFO length of es_f 14
# 2021-07-11 14:35:18,105 INFO patient: patient075, phase: ED, files: 14
# 2021-07-11 14:35:18,106 INFO Create DataGenerator
# 2021-07-11 14:35:18,106 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:18,106 INFO No augmentation
# 2021-07-11 14:35:18,152 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 14:35:18,198 INFO original cmr shape(14, 128, 128)
# 2021-07-11 14:35:18,365 INFO (14, 128, 128, 2)
# 2021-07-11 14:35:18,367 INFO (14, 128, 128)
# 2021-07-11 14:35:18,367 INFO (14, 128, 128)
# 2021-07-11 14:35:18,368 INFO (14, 128, 128)
# 2021-07-11 14:35:18,370 INFO patient: patient075, phase: ES, files: 14
# 2021-07-11 14:35:18,371 INFO Create DataGenerator
# 2021-07-11 14:35:18,371 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:18,371 INFO No augmentation
# 2021-07-11 14:35:18,416 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 14:35:18,460 INFO original cmr shape(14, 128, 128)
# 2021-07-11 14:35:18,626 INFO (14, 128, 128, 2)
# 2021-07-11 14:35:18,628 INFO (14, 128, 128)
# 2021-07-11 14:35:18,629 INFO (14, 128, 128)
# 2021-07-11 14:35:18,629 INFO (14, 128, 128)
# 2021-07-11 14:35:18,632 INFO patient087
# 2021-07-11 14:35:18,632 INFO 16
# 2021-07-11 14:35:18,632 INFO length of ed_f 8
# 2021-07-11 14:35:18,633 INFO length of es_f 8
# 2021-07-11 14:35:18,633 INFO patient: patient087, phase: ED, files: 8
# 2021-07-11 14:35:18,633 INFO Create DataGenerator
# 2021-07-11 14:35:18,633 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:18,634 INFO No augmentation
# 2021-07-11 14:35:18,662 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 14:35:18,689 INFO original cmr shape(8, 128, 128)
# 2021-07-11 14:35:18,840 INFO (8, 128, 128, 2)
# 2021-07-11 14:35:18,842 INFO (8, 128, 128)
# 2021-07-11 14:35:18,842 INFO (8, 128, 128)
# 2021-07-11 14:35:18,843 INFO (8, 128, 128)
# 2021-07-11 14:35:18,845 INFO patient: patient087, phase: ES, files: 8
# 2021-07-11 14:35:18,845 INFO Create DataGenerator
# 2021-07-11 14:35:18,845 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:18,846 INFO No augmentation
# 2021-07-11 14:35:18,873 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 14:35:18,899 INFO original cmr shape(8, 128, 128)
# 2021-07-11 14:35:19,054 INFO (8, 128, 128, 2)
# 2021-07-11 14:35:19,056 INFO (8, 128, 128)
# 2021-07-11 14:35:19,056 INFO (8, 128, 128)
# 2021-07-11 14:35:19,056 INFO (8, 128, 128)
# 2021-07-11 14:35:19,058 INFO patient088
# 2021-07-11 14:35:19,059 INFO 32
# 2021-07-11 14:35:19,059 INFO length of ed_f 16
# 2021-07-11 14:35:19,060 INFO length of es_f 16
# 2021-07-11 14:35:19,060 INFO patient: patient088, phase: ED, files: 16
# 2021-07-11 14:35:19,060 INFO Create DataGenerator
# 2021-07-11 14:35:19,060 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 16
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:19,061 INFO No augmentation
# 2021-07-11 14:35:19,115 INFO groundtruth shape(16, 128, 128, 2)
# 2021-07-11 14:35:19,170 INFO original cmr shape(16, 128, 128)
# 2021-07-11 14:35:19,350 INFO (16, 128, 128, 2)
# 2021-07-11 14:35:19,352 INFO (16, 128, 128)
# 2021-07-11 14:35:19,352 INFO (16, 128, 128)
# 2021-07-11 14:35:19,353 INFO (16, 128, 128)
# 2021-07-11 14:35:19,356 INFO patient: patient088, phase: ES, files: 16
# 2021-07-11 14:35:19,356 INFO Create DataGenerator
# 2021-07-11 14:35:19,356 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 16
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:19,357 INFO No augmentation
# 2021-07-11 14:35:19,410 INFO groundtruth shape(16, 128, 128, 2)
# 2021-07-11 14:35:19,462 INFO original cmr shape(16, 128, 128)
# 2021-07-11 14:35:19,645 INFO (16, 128, 128, 2)
# 2021-07-11 14:35:19,647 INFO (16, 128, 128)
# 2021-07-11 14:35:19,647 INFO (16, 128, 128)
# 2021-07-11 14:35:19,647 INFO (16, 128, 128)
# 2021-07-11 14:35:19,650 INFO patient091
# 2021-07-11 14:35:19,651 INFO 16
# 2021-07-11 14:35:19,651 INFO length of ed_f 8
# 2021-07-11 14:35:19,651 INFO length of es_f 8
# 2021-07-11 14:35:19,652 INFO patient: patient091, phase: ED, files: 8
# 2021-07-11 14:35:19,652 INFO Create DataGenerator
# 2021-07-11 14:35:19,653 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:19,653 INFO No augmentation
# 2021-07-11 14:35:19,680 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 14:35:19,706 INFO original cmr shape(8, 128, 128)
# 2021-07-11 14:35:19,856 INFO (8, 128, 128, 2)
# 2021-07-11 14:35:19,857 INFO (8, 128, 128)
# 2021-07-11 14:35:19,858 INFO (8, 128, 128)
# 2021-07-11 14:35:19,858 INFO (8, 128, 128)
# 2021-07-11 14:35:19,861 INFO patient: patient091, phase: ES, files: 8
# 2021-07-11 14:35:19,861 INFO Create DataGenerator
# 2021-07-11 14:35:19,861 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 8
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:19,862 INFO No augmentation
# 2021-07-11 14:35:19,888 INFO groundtruth shape(8, 128, 128, 2)
# 2021-07-11 14:35:19,918 INFO original cmr shape(8, 128, 128)
# 2021-07-11 14:35:20,088 INFO (8, 128, 128, 2)
# 2021-07-11 14:35:20,090 INFO (8, 128, 128)
# 2021-07-11 14:35:20,090 INFO (8, 128, 128)
# 2021-07-11 14:35:20,090 INFO (8, 128, 128)
# 2021-07-11 14:35:20,092 INFO patient093
# 2021-07-11 14:35:20,093 INFO 20
# 2021-07-11 14:35:20,093 INFO length of ed_f 10
# 2021-07-11 14:35:20,094 INFO length of es_f 10
# 2021-07-11 14:35:20,094 INFO patient: patient093, phase: ED, files: 10
# 2021-07-11 14:35:20,094 INFO Create DataGenerator
# 2021-07-11 14:35:20,095 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:20,095 INFO No augmentation
# 2021-07-11 14:35:20,129 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:20,163 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:20,330 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:20,331 INFO (10, 128, 128)
# 2021-07-11 14:35:20,332 INFO (10, 128, 128)
# 2021-07-11 14:35:20,332 INFO (10, 128, 128)
# 2021-07-11 14:35:20,334 INFO patient: patient093, phase: ES, files: 10
# 2021-07-11 14:35:20,335 INFO Create DataGenerator
# 2021-07-11 14:35:20,335 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 10
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:20,336 INFO No augmentation
# 2021-07-11 14:35:20,371 INFO groundtruth shape(10, 128, 128, 2)
# 2021-07-11 14:35:20,405 INFO original cmr shape(10, 128, 128)
# 2021-07-11 14:35:20,562 INFO (10, 128, 128, 2)
# 2021-07-11 14:35:20,564 INFO (10, 128, 128)
# 2021-07-11 14:35:20,564 INFO (10, 128, 128)
# 2021-07-11 14:35:20,565 INFO (10, 128, 128)
# 2021-07-11 14:35:20,567 INFO patient095
# 2021-07-11 14:35:20,567 INFO 28
# 2021-07-11 14:35:20,568 INFO length of ed_f 14
# 2021-07-11 14:35:20,568 INFO length of es_f 14
# 2021-07-11 14:35:20,568 INFO patient: patient095, phase: ED, files: 14
# 2021-07-11 14:35:20,569 INFO Create DataGenerator
# 2021-07-11 14:35:20,570 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:20,570 INFO No augmentation
# 2021-07-11 14:35:20,618 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 14:35:20,666 INFO original cmr shape(14, 128, 128)
# 2021-07-11 14:35:20,845 INFO (14, 128, 128, 2)
# 2021-07-11 14:35:20,848 INFO (14, 128, 128)
# 2021-07-11 14:35:20,848 INFO (14, 128, 128)
# 2021-07-11 14:35:20,849 INFO (14, 128, 128)
# 2021-07-11 14:35:20,853 INFO patient: patient095, phase: ES, files: 14
# 2021-07-11 14:35:20,853 INFO Create DataGenerator
# 2021-07-11 14:35:20,854 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 14
#  Augment: False
#  Thread workers: 8
# 2021-07-11 14:35:20,854 INFO No augmentation
# 2021-07-11 14:35:20,902 INFO groundtruth shape(14, 128, 128, 2)
# 2021-07-11 14:35:20,951 INFO original cmr shape(14, 128, 128)
# 2021-07-11 14:35:21,129 INFO (14, 128, 128, 2)
# 2021-07-11 14:35:21,131 INFO (14, 128, 128)
# 2021-07-11 14:35:21,131 INFO (14, 128, 128)
# 2021-07-11 14:35:21,132 INFO (14, 128, 128)
# 2021-07-11 14:35:21,135 INFO done! Check the /mnt/ssd/git/wft21_septum_landmark_detection/data/temp_predictions/k-fold_fold3folder for files

# %% [markdown]
# # Undo the generator steps
#
# - if you want to plot the predictions onto the original CMR images, you need to reverse the generator steps. This is currently not implemented nor needed.
#
# - If we have masks, undo the cropping/padding, resampling etc. so that our masks have the same size/spacing and name as our input volumes
# - If we have regression coordinates, make sure that they could be applied on the input volumes
