# %% [markdown]
# # Use the model in a inference behaviour

# %% [markdown]
# 1. Load a cv config with all experiment parameters
# 2. Load the corresponding data,
# 3. create a train and validation generator with the given parameters, exclusive the augmentation parameters
# 4. reconstruct the model with the given parameters, (we have custom loss functions, simple model.load() will not work)
# 5. load and apply the corresponding weights (with respect to the distributed training strategy)
# 6. predict the targt vectors with the train and val generators (make sure that we change the batchsize to 1, and avoid shuffle so that we get all files)
# 7. write the gt and predictions as numpy into the corresponding experiment folder

# %%
# ------------------------------------------define logging and working directory
from ProjectRoot import change_wd_to_project_root
change_wd_to_project_root()
from src.utils.Tensorflow_helper import choose_gpu_by_id
# ------------------------------------------define GPU id/s to use
GPU_IDS = '0,1'
GPUS = choose_gpu_by_id(GPU_IDS)
print(GPUS)
# ------------------------------------------jupyter magic config
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
# ------------------------------------------ import helpers
# this should import glob, os, and some other standard libs to keep this cell clean
# local imports
from src.utils.Notebook_imports import *
from src.utils.Utils_io import Console_and_file_logger, init_config

# import external libs
from tensorflow.python.client import device_lib
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
import cv2
import pandas as pd
import numpy as np
from ipyfilechooser import FileChooser
import nrrd as nrrd # https://pypi.org/project/pynrrd/
from src.data.Generators import DataGenerator
# Out:
# search for root_dir and set working directory
# Working directory set to: /mnt/ssd/git/wft21_septum_landmark_detection
# ['/gpu:0', '/gpu:1']

# %% [markdown]
# # Load a config into the global namespace

# %%
exp_config_chooser = FileChooser(os.path.join(os.getcwd(),'exp/cv_baseline'), '')
display(exp_config_chooser)
@interact_manual
def load_config():

    global exp_config_chooser, config
    """
    load an experiment config
    """
    if 'exp_config_chooser' in globals():
        config_file  = exp_config_chooser.selected
    else:
        print('no config chooser found')

    # load the experiment config
    with open(config_file, encoding='utf-8') as data_file:
        config = json.loads(data_file.read())
    globals().update(config)
    Console_and_file_logger(EXPERIMENT, logging.INFO)
    logging.info('Loaded config for experiment: {}'.format(config['EXPERIMENT']))
# Out:
# FileChooser(path='/mnt/ssd/git/wft21_septum_landmark_detection/exp/cv_baseline', filename='', title='HTML(valu…
# interactive(children=(Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widge…

# %% [markdown]
# # Load the corresponding file names for this fold

# %%
# Load SAX volumes
from src.data.Dataset import get_trainings_files
x_train_sax, y_train_sax, x_val_sax, y_val_sax = get_trainings_files(data_path=DATA_PATH_SAX,
                                                                     path_to_folds_df=DF_FOLDS,
                                                                     fold=FOLD)
logging.info('SAX train CMR: {}, SAX train masks: {}'.format(len(x_train_sax), len(y_train_sax)))
logging.info('SAX val CMR: {}, SAX val masks: {}'.format(len(x_val_sax), len(y_val_sax)))
# Out:
# 2021-07-01 11:42:01,808 INFO Found 1902 images/masks in /mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39
# 2021-07-01 11:42:01,809 INFO Patients train: 75
# 2021-07-01 11:42:01,868 INFO Selected 1426 of 1902 files with 75 of 100 patients for training fold 0
# 2021-07-01 11:42:01,868 INFO SAX train CMR: 1426, SAX train masks: 1426
# 2021-07-01 11:42:01,869 INFO SAX val CMR: 476, SAX val masks: 476
# this is the output of get_training_files. Good luck:['/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z0_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z1_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z2_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z3_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z4_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z5_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z6_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z7_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z8_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t01_z9_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z0_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z1_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z2_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z3_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z4_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z5_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z6_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z7_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z8_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient003__t15_z9_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z0_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z1_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z2_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z3_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z4_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z5_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z6_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z7_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z8_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t01_z9_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z0_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z1_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z2_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z3_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z4_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z5_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z6_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z7_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z8_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient004__t15_z9_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z0_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z1_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z2_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z3_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z4_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z5_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z6_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z7_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z8_img.nrrd', '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39/patient005__t01_z9_img.nrrd ...

# %% [markdown]
# # Create the same the train and val generators as used for the training of this model
#
# Make sure that:
# - no shuffle
# - no augmentation (classic and temporal)
# - batchsize equal 1

# %%
# # logging.getLogger().setLevel(logging.INFO)
# from src.data.Generators import PhaseRegressionGenerator
# config['SHUFFLE'] = False
# config['AUGMENT'] = False
# config['AUGMENT_PHASES'] = False
# config['BATCHSIZE'] = 1
# batch_generator = PhaseRegressionGenerator(x_train_sax, x_train_sax, config=config)
# # create another config for the validation data, 
# # by this we can have a different set of parameters for both generators
# val_config = config.copy()
# validation_generator = PhaseRegressionGenerator(x_val_sax, x_val_sax, config=val_config)
# Out:
# 2021-07-01 11:49:37,050 INFO Create DataGenerator
# 2021-07-01 11:49:37,056 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 1426
#  Augment: False
#  Thread workers: 8
# 2021-07-01 11:49:37,056 INFO No augmentation
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8d4470ad9fa3> in <module>
#       5 config['AUGMENT_PHASES'] = False
#       6 config['BATCHSIZE'] = 1
# ----> 7 batch_generator = PhaseRegressionGenerator(x_train_sax, x_train_sax, config=config)
#       8 # create another config for the validation data,
#       9 # by this we can have a different set of parameters for both generators
#
# /mnt/ssd/git/wft21_septum_landmark_detection/src/data/Generators.py in __init__(self, x, y, config)
#     641         # opens a dataframe with cleaned phases per patient
#     642         self.METADATA_FILE = config.get('DF_META', '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase')
# --> 643         df = pd.read_csv(self.METADATA_FILE)
#     644         self.DF_METADATA = df[['patient', 'ED#', 'MS#', 'ES#', 'PF#', 'MD#']]
#     645
#
# ~/anaconda3/envs/foo/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/envs/foo/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/anaconda3/envs/foo/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~/anaconda3/envs/foo/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~/anaconda3/envs/foo/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase'

# %%
# DataGenerator for SAX, changed from PhaseRegression Generator
# logging.getLogger().setLevel(logging.INFO)
from src.data.Generators import DataGenerator
config['SHUFFLE'] = False
config['AUGMENT'] = False
config['AUGMENT_PHASES'] = False
config['BATCHSIZE'] = 1
batch_generator = DataGenerator(x_train_sax, x_train_sax, config=config)
# create another config for the validation data, 
# by this we can have a different set of parameters for both generators
val_config = config.copy()
validation_generator = DataGenerator(x_val_sax, x_val_sax, config=val_config)
# Out:
# 2021-07-01 11:58:45,436 INFO Create DataGenerator
# 2021-07-01 11:58:45,445 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 1426
#  Augment: False
#  Thread workers: 8
# 2021-07-01 11:58:45,446 INFO No augmentation
# 2021-07-01 11:58:45,446 INFO Create DataGenerator
# 2021-07-01 11:58:45,449 INFO Datagenerator created with:
#  shape: [128, 128]
#  spacing: [1.8, 1.8]
#  batchsize: 1
#  Scaler: MinMax
#  Images: 476
#  Augment: False
#  Thread workers: 8
# 2021-07-01 11:58:45,449 INFO No augmentation

# %%
config
# Out:
# {'GPU_IDS': '0,1',
#  'GPUS': ['/gpu:0', '/gpu:1'],
#  'SEED': 42,
#  'EXPERIMENT': 'temp/spacing_1_8/',
#  'EXPERIMENTS_ROOT': 'exp/',
#  'EXP_PATH': 'exp/temp/spacing_1_8/2021-05-26_13_40',
#  'MODEL_PATH': 'exp/temp/spacing_1_8/2021-05-26_13_40/model',
#  'TENSORBOARD_PATH': 'exp/temp/spacing_1_8/2021-05-26_13_40/tensorboard_logs',
#  'CONFIG_PATH': 'exp/temp/spacing_1_8/2021-05-26_13_40/config',
#  'HISTORY_PATH': 'exp/temp/spacing_1_8/2021-05-26_13_40/history',
#  'DATA_PATH_SAX': '/mnt/ssd/data/WFT_MRT21/Export_2021-05-26_13_39',
#  'DF_FOLDS': '/mnt/ssd/data/WFT_MRT21/df_kfold.csv',
#  'DF_META': '/mnt/ssd/data/gcn/02_imported_4D_unfiltered/SAx_3D_dicomTags_phase',
#  'FOLD': 0,
#  'BATCHSIZE': 1,
#  'GENERATOR_WORKER': 8,
#  'EPOCHS': 100,
#  'DIM': [128, 128],
#  'SPACING': [1.8, 1.8],
#  'DEPTH': 4,
#  'FILTERS': 32,
#  'M_POOL': [2, 2],
#  'F_SIZE': [3, 3],
#  'BN_FIRST': False,
#  'BATCH_NORMALISATION': True,
#  'PAD': 'same',
#  'KERNEL_INIT': 'he_normal',
#  'OPTIMIZER': 'adam',
#  'ACTIVATION': 'relu',
#  'LEARNING_RATE': 0.0001,
#  'REDUCE_LR_ON_PLAEAU_PATIENCE': 5,
#  'DECAY_FACTOR': 0.7,
#  'POLY_LR_DECAY': False,
#  'MIN_LR': 1e-12,
#  'DROPOUT_MIN': 0.3,
#  'DROPOUT_MAX': 0.5,
#  'MONITOR_FUNCTION': 'loss',
#  'MONITOR_MODE': 'min',
#  'SAVE_MODEL_FUNCTION': 'loss',
#  'SAVE_MODEL_MODE': 'min',
#  'MODEL_PATIENCE': 20,
#  'SAVE_LEARNING_PROGRESS_AS_TF': True,
#  'IMG_CHANNELS': 1,
#  'MASK_VALUES': [1, 2],
#  'MASK_CLASSES': 2,
#  'BORDER_MODE': 4,
#  'IMG_INTERPOLATION': 1,
#  'MSK_INTERPOLATION': 0,
#  'AUGMENT': False,
#  'AUGMENT_PROB': 0.8,
#  'SHUFFLE': False,
#  'RESAMPLE': True,
#  'HIST_MATCHING': False,
#  'SCALER': 'MinMax',
#  'LOSS_FUNCTION': 'bce_dice_loss',
#  'AUGMENT_PHASES': False}

# %% [markdown]
# # Load the model, load and set the corresponding weights

# %%
# from src.models.Models import create_PhaseRegressionModel
# # create a model
# model = create_PhaseRegressionModel(config)
# model.load_weights(os.path.join(config['MODEL_PATH'],'model.h5'))
# logging.info('loaded model weights as h5 file')
# Out:
# 2021-03-04 07:49:41,777 INFO loaded model weights as h5 file
# Shape after the temporal encoder
# (None, 36, 8, 4, 4, 512)
# Shape after GAP
# (None, 36, 512)
# Shape after Bi-LSTM layer
# (None, 36, 512)
# Shape after final conv layer
# (None, 36, 5)

# %%
# Create Neural Network for SAX as Unet, changed from PhaseRegressionModel
import src.models.Unets as modelmanager
# create a model
logging.info('Create model')
model = modelmanager.create_unet(config)
model.load_weights(os.path.join(config['MODEL_PATH'],'model.h5'))
logging.info('loaded model weights as h5 file')
model.summary()
# Out:
# 2021-07-01 12:21:53,760 INFO Create model
# (None, 128, 128, 1)
# 2021-07-01 12:21:54,752 INFO loaded model weights as h5 file
# Model: "unet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 32) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 32) 9248        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 128, 128, 32) 128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 32)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   18496       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64, 64, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   36928       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 128)  73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 128)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 128)  147584      dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 128)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  295168      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 256)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 256)  590080      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 256)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 8, 8, 512)    1180160     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 512)    2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 512)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 512)    2359808     dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 8, 8, 512)    2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 16, 16, 512)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 256)  1179904     up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 512)  0           conv2d_32[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 256)  1024        conv2d_33[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 256)  590080      dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 256)  1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 256)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 128)  295040      up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 256)  0           conv2d_35[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 128)  512         conv2d_36[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 128)  147584      dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 64)   73792       up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           conv2d_38[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64, 64, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64, 64, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 64)   36928       dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64, 64, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 64) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 128, 128, 32) 18464       up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 64) 0           conv2d_41[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 128, 128, 32) 128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 128, 128, 32) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 32) 9248        dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 128, 128, 32) 128         conv2d_43[0][0]
# __________________________________________________________________________________________________
# unet (Conv2D)                   (None, 128, 128, 2)  66          batch_normalization_35[0][0]
# ==================================================================================================
# Total params: 8,641,730
# Trainable params: 8,635,842
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# # Predict on the validation split

# %%
# predict on the validation generator
preds = model.predict(validation_generator)
logging.info(preds.shape)
# Out:
# 2021-07-01 12:49:09,863 INFO (476, 128, 128, 2)

# %%
# # currently_implementing:  predict on the training split
# preds = model.predict(batch_generator)
# logging.info(preds.shape)

# %% [markdown]
# # Create one numpy object from it

# %%
# get all ground truth vectors
gts = np.stack([np.squeeze(y) for x, y in validation_generator])
logging.info(gts.shape)
# Out:
# 2021-07-01 15:32:57,513 INFO (476, 128, 128, 2)

# %%
gts_cmr = np.stack([np.squeeze(x) for x, y in validation_generator])
logging.info(gts_cmr.shape)
# Out:
# 2021-07-01 15:32:59,821 INFO (476, 128, 128)

# %% [markdown]
# # Save gt and pred into the experiment folder

# %%
pred_path = os.path.join(config['EXP_PATH'], 'pred_'+ str(datetime.datetime.now().strftime("%Y-%m-%d_%H_%M")))
ensure_dir(pred_path)
pred_filename = os.path.join(pred_path, 'gtpred_fold{}.npy'.format(config['FOLD'])) #names file according to fold
np.save(pred_filename, np.stack([gts, preds], axis=0))
logging.info('saved as: \n{} \ndone!'.format(pred_filename))
# Out:
# 2021-07-01 12:49:12,918 INFO saved as:
# exp/temp/spacing_1_8/2021-05-26_13_40/pred_2021-07-01_12_49/gtpred_fold0.npy
# done!

# %%
#np.load('/mnt/ssd/git/wft21_septum_landmark_detection/{}'.format(pred_filename))

stack = np.load('/mnt/ssd/git/wft21_septum_landmark_detection/{}'.format(pred_filename))
print('the shape of the numpy.stack is' + np.shape(stack))
print(('loading from: /mnt/ssd/git/wft21_septum_landmark_detection/{}'.format(pred_filename)))

#for-loop over stack --> reading numpy and transferring with pynrrd. pad_and_crop function applied. saving with the name of original file.
# Out:
# (2, 476, 128, 128, 2)

# %%
stack.max()
# Out:
# 1.0

# %%
import SimpleITK as sitk
gts = stack[0]
preds = stack[1]

# upper = 1, lower == 2
# transform to int representation (one-hot)
gts_flat = np.zeros((gts.shape[:-1]))
gts_flat[gts[...,0]>0.5] = 1
gts_flat[gts[...,1]>0.5] = 2

preds_flat = np.zeros((gts.shape[:-1]))
preds_flat[preds[...,0]>0.5] = 1
preds_flat[preds[...,1]>0.5] = 2
print(preds_flat.shape)
gt_sitks = [sitk.GetImageFromArray(elem) for elem in gts_flat]
pred_sitks = [sitk.GetImageFromArray(elem) for elem in preds_flat]
# Out:
# (476, 128, 128)

# %%
# write 3d_nrrd file to disk
sitk.WriteImage(sitk.GetImageFromArray(np.stack(preds_flat[:10], axis=0)), '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/3d_temp.nrrd')

# %%
# write 3d_nrrd file to disk
sitk.WriteImage(sitk.GetImageFromArray(np.stack(gts_flat[:10], axis=0)), '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/3d_temp_gt.nrrd')

# %%
os.path.basename(x_val_sax[0])
# Out:
# 'patient001__t01_z0_img.nrrd'

# %%
export_path = '/mnt/ssd/git/wft21_septum_landmark_detection/data/temp/'
ensure_dir(export_path)
_ = [sitk.WriteImage(img, '{}_{}'.format(export_path, os.path.basename(f_name))) for img, f_name in zip(gt_sitks, x_val_sax)]

# %%
from src.visualization.Visualize import show_2D_or_3D
@interact
def show_predictions(elem = (0,len(preds_flat)-1)):
    elem = gts_flat[elem]
    print(elem.shape)
    show_2D_or_3D(elem)
# Out:
# interactive(children=(IntSlider(value=237, description='elem', max=475), Output()), _dom_classes=('widget-inte…

# %%
from src.visualization.Visualize import show_2D_or_3D
@interact
def show_predictions(elem = (0,len(x_val_sax))):
    temp = x_val_sax[elem]
    cmr = sitk.ReadImage(temp)
    cmr = sitk.GetArrayFromImage(cmr)
    temp = temp.replace('img', 'msk')
    temp = sitk.ReadImage(temp)
    temp = sitk.GetArrayFromImage(temp)
    #plt.imshow(temp, cmap='gray')
    
    show_2D_or_3D(cmr, temp)
# Out:
# interactive(children=(IntSlider(value=238, description='elem', max=476), Output()), _dom_classes=('widget-inte…

# %%
from src.visualization.Visualize import show_2D_or_3D
@interact
def show_predictions(elem = (0,gts.shape[0])):
    temp = gts_cmr[elem]
    msk = gts_flat[elem]
    print(msk.shape)
    #plt.imshow(temp, cmap='gray')
    plt.imshow(msk, alpha=0.8)
    #show_2D_or_3D(temp, msk)
# Out:
# interactive(children=(IntSlider(value=238, description='elem', max=476), Output()), _dom_classes=('widget-inte…

# %%
generator = batch_generator
@interact
def select_image_in_batch(batch = (0,len(generator)-1, 1), im = (0,config['BATCHSIZE']- 1, 1), slice_n=(1,11), save=False, filepath='data/temp/', filename='temp_x.npy'):
    
    global x, y
    x, y = generator.__getitem__(batch)
    info('selected batch : ' + str(batch))
    # logging level == debug --> visualise the generator steps
    info('X shape: {}, Y shape: {}'.format(x.shape, y.shape))
    show_2D_or_3D(x[im], y[im], interpol='bilinear',dpi=100,f_size=(5,5))
    plt.show()
    
    plt.hist(x[im].flatten())
    plt.show()
    if save:
        ensure_dir(filepath)
        np.save(os.path.join(filepath, filename), x[im])
        logging.info('saved to {}'.format(os.path.join(filepath, filename)))
# Out:
# interactive(children=(IntSlider(value=712, description='batch', max=1425), IntSlider(value=0, description='im'…

# %% [markdown]
# # Undo the generator steps
#
# - If we have masks, undo the cropping/padding, resampling etc. so that our masks have the same size/spacing and name as our input volumes
# - If we have regression coordinates, make sure that they could be applied on the input volumes

# %% [markdown]
# # Load the gts, predictions testwise

# %% [markdown]
# ## Converting numpy predictions into nrrd via pynrrd

# %%
# # Some sample numpy data

# data = np.zeros((5,4,3,2))
# filename = 'testdata.nrrd'

# # Write to a NRRD file
# nrrd.write(filename, data)

# # Read the data back from file
# readdata, header = nrrd.read(filename)
# print(readdata.shape)
# print(header)
